# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# changing the working directory
# %cd '/content/drive/MyDrive/Experiment1'
# Out:
# /content/drive/MyDrive/Experiment1

# %%
# !ls
# Out:
# feature_extraction_training_and_valdiation_hw.ipynb    Training_Audio_Files    Validation_MS_PCEN
# feature_extraction_training_and_valdiation_nohw.ipynb  Training_MS_PCEN
# model.ipynb					       Validation_Audio_Files

# %% [markdown]
# ### MS-PCEN for Training (MK)

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

audio_dir = r'/content/drive/MyDrive/Experiment1/Training_Audio_Files/DC'
spectrogram_dir = r'/content/drive/MyDrive/Experiment1/Training_MS_PCEN/DC'

Training = True # Statement: If it is true, you will generate MS-PCEN with agumentation

os.makedirs(spectrogram_dir, exist_ok=True)

# pitch shifting
shift_steps = [8, 4] # rate of the semitones

# time shifting
time_shifts = [1.0] # time in second
count = 0

for audio_file in os.listdir(audio_dir):
    count = count + 1
    print(f"The data sample {audio_file} is processed: {count}/{len(os.listdir(audio_dir))}")
    audio_path = os.path.join(audio_dir, audio_file)
    audio, sr = librosa.load(audio_path, sr=6000)

    # Mel
    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=2048,
                                                 hop_length=512, win_length=2048,
                                                 n_mels=128, power=1) # I think he was using 128 as default
    mel_pcen = librosa.pcen(spectrogram, sr=sr, hop_length=512,
                            gain=0.98, bias=0.2, power=0.9,
                            time_constant=0.0004, eps=1e-6)
    plt.figure(figsize=(8, 4))
    librosa.display.specshow(mel_pcen, sr=sr, x_axis='time', y_axis='mel')
    plt.tight_layout()
    file_name = os.path.splitext(audio_file)[0]
    save_path = os.path.join(spectrogram_dir, f'{file_name}.png')
    plt.axis('off')
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
    spec_image = Image.open(save_path)
    spec_image_rgb = spec_image.convert('RGB')
    rgb_array = np.array(spec_image_rgb)
    rgb_array_norm = 255*((rgb_array-np.min(rgb_array))/(np.max(rgb_array)-np.min(rgb_array)))
    rgb_image_spec = Image.fromarray(rgb_array_norm.astype(np.uint8))
    rgb_image_spec.save(save_path)

    if Training==True:
        for shift_step in shift_steps:
            shifted_audio = librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=shift_step)

            pitch_shifted_spectrogram = librosa.feature.melspectrogram(y=shifted_audio, sr=sr, n_fft=2048,
                                                         hop_length=512, win_length=2048,
                                                         n_mels=128, power=1)

            pitch_shifted_mel_pcen = librosa.pcen(pitch_shifted_spectrogram, sr=sr, hop_length=512,
                                            gain=0.98, bias=0.2, power=0.9,
                                            time_constant=0.0004, eps=1e-6)

            plt.figure(figsize=(8, 4))
            librosa.display.specshow(pitch_shifted_mel_pcen, sr=sr, x_axis='time', y_axis='mel')
            plt.tight_layout()

            shifted_save_path = os.path.join(spectrogram_dir, f'{file_name}_shifted_{shift_step}.png')
            plt.axis('off')
            plt.savefig(shifted_save_path, bbox_inches='tight', pad_inches=0)
            plt.close()
            # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
            shifted_spec_image = Image.open(shifted_save_path)
            shifted_spec_image_rgb = shifted_spec_image.convert('RGB')
            shifted_spec_image_rgb_array = np.array(shifted_spec_image_rgb)
            shifted_spec_image_rgb_array_norm = 255*((shifted_spec_image_rgb_array\
                                                 -np.min(shifted_spec_image_rgb_array))\
                                                /(np.max(shifted_spec_image_rgb_array)\
                                                  -np.min(shifted_spec_image_rgb_array)))
            shifted_spec_image_rgb_im = Image.fromarray(shifted_spec_image_rgb_array_norm.astype(np.uint8))
            shifted_spec_image_rgb_im.save(shifted_save_path)

        for time_shift in time_shifts:
            # time shifting
            time_shifted_spectrogram = np.roll(mel_pcen, round((sr * time_shift)/512.0), axis=1)


            plt.figure(figsize=(8, 4))
            librosa.display.specshow(time_shifted_spectrogram, sr=sr, x_axis='time', y_axis='mel')
            plt.tight_layout()

            time_shifted_save_path = os.path.join(spectrogram_dir, f'{file_name}_shifted_{time_shift}.png')
            plt.axis('off')
            plt.savefig(time_shifted_save_path, bbox_inches='tight', pad_inches=0)
            plt.close()
            # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
            time_shifted_spec_image = Image.open(time_shifted_save_path)
            time_shifted_spec_image_rgb = time_shifted_spec_image.convert('RGB')
            time_shifted_spec_image_rgb_array = np.array(time_shifted_spec_image_rgb)
            time_shifted_spec_image_rgb_array_norm = 255*((time_shifted_spec_image_rgb_array\
                                                      -np.min(time_shifted_spec_image_rgb_array))\
                                                     /(np.max(time_shifted_spec_image_rgb_array)\
                                                       -np.min(time_shifted_spec_image_rgb_array)))
            time_shifted_spec_image_rgb_im = Image.fromarray(time_shifted_spec_image_rgb_array_norm.astype(np.uint8))
            time_shifted_spec_image_rgb_im.save(time_shifted_save_path)
# Out:
# The data sample 53010BCD_0.wav is processed: 1/60
# The data sample 53010BCD_130.wav is processed: 2/60
# The data sample 530ACBE5_140.wav is processed: 3/60
# The data sample 53010BCD_80.wav is processed: 4/60
# The data sample 52ED3E45_140.wav is processed: 5/60
# The data sample 52ED3E45_180.wav is processed: 6/60
# The data sample 53B3340A_40.wav is processed: 7/60
# The data sample 5377B2D6_220.wav is processed: 8/60
# The data sample 53B3340A_190.wav is processed: 9/60
# The data sample 53B3340A_160.wav is processed: 10/60
# The data sample 539D539E_140.wav is processed: 11/60
# The data sample 541EF71D_170.wav is processed: 12/60
# The data sample 541EF71D_120.wav is processed: 13/60
# The data sample 541EF71D_90.wav is processed: 14/60
# The data sample 541EF71D_140.wav is processed: 15/60
# The data sample 580D0FA9_10.wav is processed: 16/60
# The data sample 580D0FA9_280.wav is processed: 17/60
# The data sample 581C588D_260.wav is processed: 18/60
# The data sample 58284EA9_90.wav is processed: 19/60
# The data sample 58284EA9_260.wav is processed: 20/60
# The data sample 592A86F5_70.wav is processed: 21/60
# The data sample 58FC4D5E_70.wav is processed: 22/60
# The data sample 5939FA09_80.wav is processed: 23/60
# The data sample 5939FA09_30.wav is processed: 24/60
# The data sample 58FC4D5E_220.wav is processed: 25/60
# The data sample 58B01221_30.wav is processed: 26/60
# The data sample 58FC4D5E_0.wav is processed: 27/60
# The data sample 5900F529_0.wav is processed: 28/60
# The data sample 592A86F5_100.wav is processed: 29/60
# The data sample 5901EB40_130.wav is processed: 30/60
# The data sample 592A86F5_250.wav is processed: 31/60
# The data sample 535E35CD_50.wav is processed: 32/60
# The data sample 533BA175_30.wav is processed: 33/60
# The data sample 53764FB9_50.wav is processed: 34/60
# The data sample 5300C200_250.wav is processed: 35/60
# The data sample 53764FB9_220.wav is processed: 36/60
# The data sample 5300C200_150.wav is processed: 37/60
# The data sample 533BA175_120.wav is processed: 38/60
# The data sample 53764FB9_100.wav is processed: 39/60
# The data sample 53764FB9_10.wav is processed: 40/60
# The data sample 52FBF705_200.wav is processed: 41/60
# The data sample 5300C200_170.wav is processed: 42/60
# The data sample 533BA175_280.wav is processed: 43/60
# The data sample 536CF212_270.wav is processed: 44/60
# The data sample 5300C200_10.wav is processed: 45/60
# The data sample 5300C200_110.wav is processed: 46/60
# The data sample 54343CD1_230.wav is processed: 47/60
# The data sample 54343CD1_80.wav is processed: 48/60
# The data sample 57E5FA31_280.wav is processed: 49/60
# The data sample 57E5FA31_160.wav is processed: 50/60
# The data sample 58EB5E99_120.wav is processed: 51/60
# The data sample 581F10A5_240.wav is processed: 52/60
# The data sample 5818D109_190.wav is processed: 53/60
# The data sample 583D7135_210.wav is processed: 54/60
# The data sample 58411F66_50.wav is processed: 55/60
# The data sample 593A2B41_0.wav is processed: 56/60
# The data sample 593A2B41_60.wav is processed: 57/60
# The data sample 5908A96E_0.wav is processed: 58/60
# The data sample 597D9C7D_0.wav is processed: 59/60
# The data sample 5992D0A4_140.wav is processed: 60/60

# %% [markdown]
# ### MS-PCEN for Validation (HW)

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

audio_dir = r'/content/drive/MyDrive/Experiment1/Validation_Audio_Files/DC'
spectrogram_dir = r'/content/drive/MyDrive/Experiment1/Validation_MS_PCEN/DC'

Training = False # Statement: If it is true, you will generate MS-PCEN with agumentation

os.makedirs(spectrogram_dir, exist_ok=True)

# pitch shifting
shift_steps = [8, 4] # rate of the semitones

# time shifting
time_shifts = [1.0] # time in second
count = 0

for audio_file in os.listdir(audio_dir):
    count = count + 1
    print(f"The data sample {audio_file} is processed: {count}/{len(os.listdir(audio_dir))}")
    audio_path = os.path.join(audio_dir, audio_file)
    audio, sr = librosa.load(audio_path, sr=6000)

    # Mel
    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=2048,
                                                 hop_length=512, win_length=2048,
                                                 n_mels=128, power=1) # I think he was using 128 as default
    mel_pcen = librosa.pcen(spectrogram, sr=sr, hop_length=512,
                            gain=0.98, bias=0.2, power=0.9,
                            time_constant=0.0004, eps=1e-6)
    plt.figure(figsize=(8, 4))
    librosa.display.specshow(mel_pcen, sr=sr, x_axis='time', y_axis='mel')
    plt.tight_layout()
    file_name = os.path.splitext(audio_file)[0]
    save_path = os.path.join(spectrogram_dir, f'{file_name}.png')
    plt.axis('off')
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
    spec_image = Image.open(save_path)
    spec_image_rgb = spec_image.convert('RGB')
    rgb_array = np.array(spec_image_rgb)
    rgb_array_norm = 255*((rgb_array-np.min(rgb_array))/(np.max(rgb_array)-np.min(rgb_array)))
    rgb_image_spec = Image.fromarray(rgb_array_norm.astype(np.uint8))
    rgb_image_spec.save(save_path)

    if Training==True:
        for shift_step in shift_steps:
            shifted_audio = librosa.effects.pitch_shift(y=audio, sr=sr, n_steps=shift_step)

            pitch_shifted_spectrogram = librosa.feature.melspectrogram(y=shifted_audio, sr=sr, n_fft=2048,
                                                         hop_length=512, win_length=2048,
                                                         n_mels=128, power=1)

            pitch_shifted_mel_pcen = librosa.pcen(pitch_shifted_spectrogram, sr=sr, hop_length=512,
                                            gain=0.98, bias=0.2, power=0.9,
                                            time_constant=0.0004, eps=1e-6)

            plt.figure(figsize=(8, 4))
            librosa.display.specshow(pitch_shifted_mel_pcen, sr=sr, x_axis='time', y_axis='mel')
            plt.tight_layout()

            shifted_save_path = os.path.join(spectrogram_dir, f'{file_name}_shifted_{shift_step}.png')
            plt.axis('off')
            plt.savefig(shifted_save_path, bbox_inches='tight', pad_inches=0)
            plt.close()
            # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
            shifted_spec_image = Image.open(shifted_save_path)
            shifted_spec_image_rgb = shifted_spec_image.convert('RGB')
            shifted_spec_image_rgb_array = np.array(shifted_spec_image_rgb)
            shifted_spec_image_rgb_array_norm = 255*((shifted_spec_image_rgb_array\
                                                 -np.min(shifted_spec_image_rgb_array))\
                                                /(np.max(shifted_spec_image_rgb_array)\
                                                  -np.min(shifted_spec_image_rgb_array)))
            shifted_spec_image_rgb_im = Image.fromarray(shifted_spec_image_rgb_array_norm.astype(np.uint8))
            shifted_spec_image_rgb_im.save(shifted_save_path)

        for time_shift in time_shifts:
            # time shifting
            time_shifted_spectrogram = np.roll(mel_pcen, round((sr * time_shift)/512.0), axis=1)


            plt.figure(figsize=(8, 4))
            librosa.display.specshow(time_shifted_spectrogram, sr=sr, x_axis='time', y_axis='mel')
            plt.tight_layout()

            time_shifted_save_path = os.path.join(spectrogram_dir, f'{file_name}_shifted_{time_shift}.png')
            plt.axis('off')
            plt.savefig(time_shifted_save_path, bbox_inches='tight', pad_inches=0)
            plt.close()
            # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
            time_shifted_spec_image = Image.open(time_shifted_save_path)
            time_shifted_spec_image_rgb = time_shifted_spec_image.convert('RGB')
            time_shifted_spec_image_rgb_array = np.array(time_shifted_spec_image_rgb)
            time_shifted_spec_image_rgb_array_norm = 255*((time_shifted_spec_image_rgb_array\
                                                      -np.min(time_shifted_spec_image_rgb_array))\
                                                     /(np.max(time_shifted_spec_image_rgb_array)\
                                                       -np.min(time_shifted_spec_image_rgb_array)))
            time_shifted_spec_image_rgb_im = Image.fromarray(time_shifted_spec_image_rgb_array_norm.astype(np.uint8))
            time_shifted_spec_image_rgb_im.save(time_shifted_save_path)
# Out:
# The data sample 530120E6_180.wav is processed: 1/21
# The data sample 530120E6_0.wav is processed: 2/21
# The data sample 530120E6_280.wav is processed: 3/21
# The data sample 530120E6_100.wav is processed: 4/21
# The data sample 530120E6_140.wav is processed: 5/21
# The data sample 53472711_130.wav is processed: 6/21
# The data sample 53472711_10.wav is processed: 7/21
# The data sample 53472711_70.wav is processed: 8/21
# The data sample 5898501A_60.wav is processed: 9/21
# The data sample 59135511_180.wav is processed: 10/21
# The data sample 59039F30_110.wav is processed: 11/21
# The data sample 589868B4_30.wav is processed: 12/21
# The data sample 59135511_120.wav is processed: 13/21
# The data sample 5992164A_270.wav is processed: 14/21
# The data sample 54486945_190.wav is processed: 15/21
# The data sample 58411F66_100.wav is processed: 16/21
# The data sample 582576ED_220.wav is processed: 17/21
# The data sample 58924C41_230.wav is processed: 18/21
# The data sample 582576ED_270.wav is processed: 19/21
# The data sample 58411F66_130.wav is processed: 20/21
# The data sample 582576ED_160.wav is processed: 21/21
