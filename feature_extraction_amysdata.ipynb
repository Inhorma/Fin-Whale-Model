# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# changing the working directory
# %cd '/content/drive/MyDrive/Amy'
# Out:
# /content/drive/MyDrive/Amy

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
audio_dir = r'/content/drive/MyDrive/Amy/DC'
spectrogram_dir = r'/content/drive/MyDrive/Amy/MS_PCEN/DC'

os.makedirs(spectrogram_dir, exist_ok=True)
count = 0

for audio_file in os.listdir(audio_dir):
    count = count + 1
    print(f"The data sample {audio_file} is processed: {count}/{len(os.listdir(audio_dir))}")
    audio_path = os.path.join(audio_dir, audio_file)
    audio, sr = librosa.load(audio_path, sr=6000)

    # Mel
    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=2048,
                                                 hop_length=512, win_length=2048,
                                                 n_mels=128, power=1) # I think he was using 128 as default
    mel_pcen = librosa.pcen(spectrogram, sr=sr, hop_length=512,
                            gain=0.98, bias=0.2, power=0.9,
                            time_constant=0.0004, eps=1e-6)
    plt.figure(figsize=(8, 4))
    librosa.display.specshow(mel_pcen, sr=sr, x_axis='time', y_axis='mel')
    plt.tight_layout()
    file_name = os.path.splitext(audio_file)[0]
    save_path = os.path.join(spectrogram_dir, f'{file_name}.png')
    plt.axis('off')
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
    spec_image = Image.open(save_path)
    spec_image_rgb = spec_image.convert('RGB')
    rgb_array = np.array(spec_image_rgb)
    rgb_array_norm = 255*((rgb_array-np.min(rgb_array))/(np.max(rgb_array)-np.min(rgb_array)))
    rgb_image_spec = Image.fromarray(rgb_array_norm.astype(np.uint8))
    rgb_image_spec.save(save_path)
# Out:
# The data sample 377_24_EI_DEPLOYMENT_20240311_125039_479_300.wav is processed: 1/122
# The data sample 374_24_EI_DEPLOYMENT_20240311_070820_614_1000.wav is processed: 2/122
# The data sample 374_24_EI_DEPLOYMENT_20240314_005256_559_900.wav is processed: 3/122
# The data sample 374_24_EI_DEPLOYMENT_20240318_032950_484_1500.wav is processed: 4/122
# The data sample 374_24_EI_DEPLOYMENT_20240311_080621_126_1010.wav is processed: 5/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_163539_736_420.wav is processed: 6/122
# The data sample 374_24_EI_DEPLOYMENT_20240314_125803_148_660.wav is processed: 7/122
# The data sample 374_24_EI_DEPLOYMENT_20240313_112049_149_1190.wav is processed: 8/122
# The data sample 377_24_EI_DEPLOYMENT_20240315_182128_904_1500.wav is processed: 9/122
# The data sample 374_24_EI_DEPLOYMENT_20240312_133537_252_1360.wav is processed: 10/122
# The data sample 377_24_EI_DEPLOYMENT_20240317_125349_621_490.wav is processed: 11/122
# The data sample 377_24_EI_DEPLOYMENT_20240315_123326_084_680.wav is processed: 12/122
# The data sample 374_24_EI_DEPLOYMENT_20240313_102248_621_1010.wav is processed: 13/122
# The data sample 374_24_EI_DEPLOYMENT_20240311_125623_777_1500.wav is processed: 14/122
# The data sample 377_24_EI_DEPLOYMENT_20240315_165428_202_1200.wav is processed: 15/122
# The data sample 374_24_EI_DEPLOYMENT_20240318_023149_954_490.wav is processed: 16/122
# The data sample 374_24_EI_DEPLOYMENT_20240314_012156_812_490.wav is processed: 122/122

# %%
audio_dir = r'/content/drive/MyDrive/Amy/NoDC'
spectrogram_dir = r'/content/drive/MyDrive/Amy/MS_PCEN/NoDC'

os.makedirs(spectrogram_dir, exist_ok=True)
count = 0

for audio_file in os.listdir(audio_dir):
    count = count + 1
    print(f"The data sample {audio_file} is processed: {count}/{len(os.listdir(audio_dir))}")
    audio_path = os.path.join(audio_dir, audio_file)
    audio, sr = librosa.load(audio_path, sr=6000)

    # Mel
    spectrogram = librosa.feature.melspectrogram(y=audio, sr=sr, n_fft=2048,
                                                 hop_length=512, win_length=2048,
                                                 n_mels=128, power=1) # I think he was using 128 as default
    mel_pcen = librosa.pcen(spectrogram, sr=sr, hop_length=512,
                            gain=0.98, bias=0.2, power=0.9,
                            time_constant=0.0004, eps=1e-6)
    plt.figure(figsize=(8, 4))
    librosa.display.specshow(mel_pcen, sr=sr, x_axis='time', y_axis='mel')
    plt.tight_layout()
    file_name = os.path.splitext(audio_file)[0]
    save_path = os.path.join(spectrogram_dir, f'{file_name}.png')
    plt.axis('off')
    plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
    plt.close()
    # Following 6 lines are to convert CYMK images to RGB images with the grayscale values ranging between 0-255
    spec_image = Image.open(save_path)
    spec_image_rgb = spec_image.convert('RGB')
    rgb_array = np.array(spec_image_rgb)
    rgb_array_norm = 255*((rgb_array-np.min(rgb_array))/(np.max(rgb_array)-np.min(rgb_array)))
    rgb_image_spec = Image.fromarray(rgb_array_norm.astype(np.uint8))
    rgb_image_spec.save(save_path)
# Out:
# The data sample 374_24_EI_DEPLOYMENT_20240311_152125_095_1460.wav is processed: 1/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_192941_153_1180.wav is processed: 2/122
# The data sample 377_24_EI_DEPLOYMENT_20240317_001943_517_270.wav is processed: 3/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_051647_489_1080.wav is processed: 4/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_205641_851_1140.wav is processed: 5/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_005435_951_1050.wav is processed: 6/122
# The data sample 377_24_EI_DEPLOYMENT_20240317_053846_108_1310.wav is processed: 7/122
# The data sample 374_24_EI_DEPLOYMENT_20240316_004422_725_60.wav is processed: 8/122
# The data sample 374_24_EI_DEPLOYMENT_20240313_072847_035_1510.wav is processed: 9/122
# The data sample 377_24_EI_DEPLOYMENT_20240311_125039_479_1680.wav is processed: 10/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_195706_304_800.wav is processed: 11/122
# The data sample 374_24_EI_DEPLOYMENT_20240315_101414_783_820.wav is processed: 12/122
# The data sample 374_24_EI_DEPLOYMENT_20240315_114115_570_700.wav is processed: 13/122
# The data sample 377_24_EI_DEPLOYMENT_20240317_011743_970_70.wav is processed: 14/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_225242_797_660.wav is processed: 15/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_214147_303_1550.wav is processed: 16/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_191645_984_670.wav is processed: 17/122
# The data sample 377_24_EI_DEPLOYMENT_20240317_011743_970_1520.wav is processed: 88/122
# The data sample 374_24_EI_DEPLOYMENT_20240318_091753_650_570.wav is processed: 89/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_093640_709_1630.wav is processed: 90/122
# The data sample 377_24_EI_DEPLOYMENT_20240315_211530_322_730.wav is processed: 91/122
# The data sample 374_24_EI_DEPLOYMENT_20240316_134729_858_1170.wav is processed: 92/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_175053_610_320.wav is processed: 93/122
# The data sample 377_24_EI_DEPLOYMENT_20240311_223044_200_1210.wav is processed: 94/122
# The data sample 374_24_EI_DEPLOYMENT_20240316_050525_102_690.wav is processed: 95/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_094801_373_920.wav is processed: 96/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_074148_659_1610.wav is processed: 97/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_143803_714_1720.wav is processed: 98/122
# The data sample 374_24_EI_DEPLOYMENT_20240318_032950_484_1300.wav is processed: 99/122
# The data sample 377_24_EI_DEPLOYMENT_20240314_050810_783_880.wav is processed: 100/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_170304_905_1540.wav is processed: 101/122
# The data sample 374_24_EI_DEPLOYMENT_20240312_234442_815_1430.wav is processed: 102/122
# The data sample 377_24_EI_DEPLOYMENT_20240314_080212_200_1490.wav is processed: 103/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_013632_439_340.wav is processed: 104/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_221155_727_1320.wav is processed: 105/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_000756_670_90.wav is processed: 106/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_083840_178_10.wav is processed: 107/122
# The data sample 377_24_EI_DEPLOYMENT_20240314_210518_542_1330.wav is processed: 108/122
# The data sample 374_24_EI_DEPLOYMENT_20240317_041737_798_1370.wav is processed: 109/122
# The data sample 374_24_EI_DEPLOYMENT_20240315_000509_221_1280.wav is processed: 110/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_062459_729_1470.wav is processed: 111/122
# The data sample 374_24_EI_DEPLOYMENT_20240315_114115_570_1720.wav is processed: 112/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_101701_600_700.wav is processed: 113/122
# The data sample 377_24_EI_DEPLOYMENT_20240316_235043_269_1350.wav is processed: 114/122
# The data sample 377_24_EI_DEPLOYMENT_20240315_061623_021_200.wav is processed: 115/122
# The data sample 374_24_EI_DEPLOYMENT_20240313_173752_582_10.wav is processed: 116/122
# The data sample 377_24_EI_DEPLOYMENT_20240311_115239_027_1670.wav is processed: 117/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_142751_966_210.wav is processed: 118/122
# The data sample 377_24_EI_DEPLOYMENT_20240312_165253_138_1500.wav is processed: 119/122
# The data sample 377_24_EI_DEPLOYMENT_20240311_232844_673_1460.wav is processed: 120/122
# The data sample 374_24_EI_DEPLOYMENT_20240312_195240_689_1410.wav is processed: 121/122
# The data sample 377_24_EI_DEPLOYMENT_20240313_121302_543_520.wav is processed: 122/122
